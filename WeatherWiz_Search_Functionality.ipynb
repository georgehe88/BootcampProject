# %%
import requests

class PirateWeatherAPI:
    def __init__(self, api_key):
        self.base_url = "https://api.pirateweather.net/forecast/"
        self.api_key = api_key

    def get_weather_by_city(self, city_name):
        url = f"{self.base_url}{self.api_key}/{city_name}"
        return self._make_request(url)

    def get_weather_by_zip(self, zip_code):
        url = f"{self.base_url}{self.api_key}/{zip_code}"
        return self._make_request(url)

    def get_weather_by_coordinates(self, latitude, longitude):
        url = f"{self.base_url}{self.api_key}/{latitude},{longitude}"
        return self._make_request(url)

    def _make_request(self, url):
        response = requests.get(url)
        return response.json()

# Example usage
if __name__ == "__main__":
    api_key = "79zczrSjDkIR6wOI2bl1AIMV77l04TQr"
    weather_api = PirateWeatherAPI(api_key)

    # Search by city
    city_name = "New York"
    city_weather = weather_api.get_weather_by_city(city_name)
    print(f"Weather in {city_name}: {city_weather}")

    # Search by zip code
    zip_code = "10001"
    zip_weather = weather_api.get_weather_by_zip(zip_code)
    print(f"Weather in {zip_code}: {zip_weather}")

    # Search by coordinates
    latitude = 40.7128
    longitude = -74.0060
    coordinates_weather = weather_api.get_weather_by_coordinates(latitude, longitude)
    print(f"Weather at coordinates ({latitude}, {longitude}): {coordinates_weather}")
# Out:
# Weather in New York: {'error': 'could not JSON decode Lambda function response: statusCode validation failed', 'message': 'Bad Gateway'}
# Weather in 10001: {'error': 'could not JSON decode Lambda function response: statusCode validation failed', 'message': 'Bad Gateway'}
# Weather at coordinates (40.7128, -74.006): {'latitude': 40.7128, 'longitude': -74.006, 'timezone': 'America/New_York', 'offset': -4.0, 'elevation': 62, 'currently': {'time': 1711986840, 'summary': 'Cloudy', 'icon': 'cloudy', 'nearestStormDistance': 0, 'nearestStormBearing': 0, 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipType': 'none', 'temperature': 54.12, 'apparentTemperature': 53.49, 'dewPoint': 42.87, 'humidity': 0.69, 'pressure': 1013.1, 'windSpeed': 4.55, 'windGust': 6.14, 'windBearing': 133, 'cloudCover': 1.0, 'uvIndex': 1.63, 'visibility': 10.0, 'ozone': 399.43}, 'minutely': {'summary': 'Clear', 'icon': 'clear', 'data': [{'time': 1711986840, 'precipIntensity': 0.0, 'precipProbability': 0.07, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711986900, 'precipIntensity': 0.0, 'precipProbability': 0.07, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711986960, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987020, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987080, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987140, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987200, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987260, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987320, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987380, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987440, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987500, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987560, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987620, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987680, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987740, 'precipIntensity': 0.0, 'precipProbability': 0.08, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987800, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987860, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987920, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711987980, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711988040, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711988100, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711988160, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711988220, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711988280, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711988340, 'precipIntensity': 0.0, 'precipProbability': 0.09, 'precipIntensityError': 0.01, 'precipType': 'none'}, {'time': 1711988400, 'precipIntensity': 0.0, 'precipProbability': 0.09,  ...

# %%
import requests

BASE_URL = "https://api.pirateweather.net/forecast/"
API_KEY = "9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ"
LATITUDE = "40.7128"
LONGITUDE = "-74.006"
TIME = "current"
EXCLUDE = "minutely,daily"
UNITS = "auto"
EXTEND = "hourly"
TZ = "auto"

url = f"{BASE_URL}{API_KEY}/{LATITUDE},{LONGITUDE},{TIME}?exclude={EXCLUDE}&units={UNITS}&extend={EXTEND}&tz={TZ}"

response = requests.get(url).json()
print(response)
# Out:
# {'latitude': 51.5, 'longitude': 0.1276, 'timezone': 'Europe/London', 'offset': 1.0, 'elevation': 7, 'currently': {'time': 1712001060, 'summary': 'Cloudy', 'icon': 'cloudy', 'nearestStormDistance': 0, 'nearestStormBearing': 0, 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipType': 'none', 'temperature': 45.32, 'apparentTemperature': 41.53, 'dewPoint': 41.54, 'humidity': 0.87, 'pressure': 989.75, 'windSpeed': 6.98, 'windGust': 21.09, 'windBearing': 186, 'cloudCover': 0.8, 'uvIndex': 0.03, 'visibility': 10.0, 'ozone': 499.39}, 'hourly': {'summary': 'Cloudy', 'icon': 'cloudy', 'data': [{'time': 1711998000, 'icon': 'clear-night', 'summary': 'Clear', 'precipIntensity': 0.0011, 'precipProbability': 0.34, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0011, 'precipType': 'rain', 'temperature': 46.24, 'apparentTemperature': 42.53, 'dewPoint': 41.97, 'humidity': 0.85, 'pressure': 989.43, 'windSpeed': 7.2, 'windGust': 19.45, 'windBearing': 194, 'cloudCover': 0.13, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 496.64}, {'time': 1712001600, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0005, 'precipProbability': 0.17, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0005, 'precipType': 'rain', 'temperature': 45.32, 'apparentTemperature': 41.53, 'dewPoint': 41.54, 'humidity': 0.87, 'pressure': 989.75, 'windSpeed': 6.98, 'windGust': 21.09, 'windBearing': 186, 'cloudCover': 0.8, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 499.39}, {'time': 1712005200, 'icon': 'clear-night', 'summary': 'Clear', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 45.11, 'apparentTemperature': 40.94, 'dewPoint': 41.56, 'humidity': 0.87, 'pressure': 989.94, 'windSpeed': 7.66, 'windGust': 22.13, 'windBearing': 184, 'cloudCover': 0.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 499.12}, {'time': 1712008800, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 45.5, 'apparentTemperature': 40.8, 'dewPoint': 42.29, 'humidity': 0.89, 'pressure': 990.3, 'windSpeed': 9.04, 'windGust': 23.56, 'windBearing': 193, 'cloudCover': 1.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 494.26}, {'time': 1712012400, 'icon': 'partly-cloudy-night', 'summary': 'Partly Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 46.19, 'apparentTemperature': 41.12, 'dewPoint': 43.44, 'humidity': 0.9, 'pressure': 990.61, 'windSpeed': 10.44, 'windGust': 25.27, 'windBearing': 209, 'cloudCover': 0.42, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 493.56}, {'time': 1712016000, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 46.56, 'apparentTemperature': 41.13, 'dewPoint': 44.32, 'humidity': 0.92, 'pressure': 990.95, 'windSpeed': 11.8, 'windGust': 25.76, 'windBearing': 214, 'cloudCover': 1.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 493.17}, {'time': 1712019600, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0019, 'precipProbability': 0.05, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0019, 'precipType': 'rain', 'temperature': 48.24, 'apparentTemperature': 42.5, 'dewPoint': 43.54, 'humidity': 0.84, 'pressure': 991.13, 'windSpeed': 14.43, 'windGust': 25.68, 'windBearing': 217, 'cloudCover': 0.97, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 489.32}, {'time': 1712023200, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0025, 'precipProbability': 0.07, 'precipIntensityError': 0.01, 'precipAccumulation': 0.0025, 'precipType': 'rain', 'temperature': 47.83, 'apparentTemperature': 42.01, 'dewPoint': 44.04, 'humidity': 0.86, 'pressure': 991.36, 'windSpeed': 14.34, 'win ...

# %%
import requests

BASE_URL = "https://api.pirateweather.net/forecast/"
API_KEY = "9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ"

def get_weather(location):
    # Check if the location is numeric (assuming it's coordinates if numeric)
    if location.replace('.', '').isdigit():
        # Assume coordinates
        latitude, longitude = location.split(',')
        url = f"{BASE_URL}{API_KEY}/{latitude},{longitude},current"
    else:
        # Check if the location contains a comma (assuming it's city, coordinates)
        if ',' in location:
            # Assume city, coordinates
            city, coordinates = location.split(',', 1)
            url = f"{BASE_URL}{API_KEY}/{coordinates},current"
        else:
            # Assume city or zip code
            url = f"{BASE_URL}{API_KEY}/{location},current"

    # Add additional parameters
    url += "?exclude=minutely,daily&units=auto&extend=hourly&tz=auto"

    # Send the request and get the response
    response = requests.get(url).json()
    return response

# Example usage:
location = input("Enter city, zip code, or coordinates: ")
weather_data = get_weather(location)
print(weather_data)
# Out:
# Enter city, zip code, or coordinates: new york
# {'error': 'could not JSON decode Lambda function response: statusCode validation failed', 'message': 'Bad Gateway'}

# %%
import requests

BASE_URL = "https://api.pirateweather.net/forecast/"
API_KEY = "9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ"

def get_weather(location, units='auto'):
    # Construct the URL based on the location and API key
    url = f"{BASE_URL}{API_KEY}/{location}?&units={units}"

    try:
        # Send the request and get the response
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        response.raise_for_status()

        # Parse JSON response
        weather_data = response.json()
        return weather_data
    except requests.exceptions.RequestException as e:
        # Print error message if request was not successful
        print(f"HTTP error occurred: {e}")
        return None

# Example usage:
location = input("Enter city, zip code, or coordinates: ")
weather_data = get_weather(location)
if weather_data:
    print(weather_data)
# Out:
# Enter city, zip code, or coordinates: New_York
# HTTP error occurred: 502 Server Error: Bad Gateway for url: https://api.pirateweather.net/forecast/9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ/New_York?&units=auto

# %%
import requests

BASE_URL = "https://api.pirateweather.net/forecast/"
API_KEY = "9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ"

def get_weather(location, units='auto'):
    try:
        # Construct the URL based on the location and API key
        url = f"{BASE_URL}{API_KEY}/{location}?exclude=minutely,daily&units={units}&extend=hourly&tz=auto"

        # Send the request and get the response
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        response.raise_for_status()

        # Parse JSON response
        weather_data = response.json()
        return weather_data
    except requests.exceptions.RequestException as e:
        # Print error message if request was not successful
        print(f"HTTP error occurred: {e}")
        return None

# Example usage:
location = f"{LATITUDE},{LONGITUDE},{TIME}"
weather_data = get_weather(location, units=UNITS)
if weather_data:
    print(weather_data)
# Out:
# {'latitude': 51.5, 'longitude': 0.1276, 'timezone': 'Europe/London', 'offset': 1.0, 'elevation': 7, 'currently': {'time': 1712001540, 'summary': 'Cloudy', 'icon': 'cloudy', 'nearestStormDistance': 0, 'nearestStormBearing': 0, 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipType': 'none', 'temperature': 45.32, 'apparentTemperature': 41.53, 'dewPoint': 41.54, 'humidity': 0.87, 'pressure': 989.75, 'windSpeed': 6.98, 'windGust': 21.09, 'windBearing': 186, 'cloudCover': 0.8, 'uvIndex': 0.03, 'visibility': 10.0, 'ozone': 499.39}, 'hourly': {'summary': 'Cloudy', 'icon': 'cloudy', 'data': [{'time': 1711998000, 'icon': 'clear-night', 'summary': 'Clear', 'precipIntensity': 0.0011, 'precipProbability': 0.34, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0011, 'precipType': 'rain', 'temperature': 46.24, 'apparentTemperature': 42.53, 'dewPoint': 41.97, 'humidity': 0.85, 'pressure': 989.43, 'windSpeed': 7.2, 'windGust': 19.45, 'windBearing': 194, 'cloudCover': 0.13, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 496.64}, {'time': 1712001600, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0005, 'precipProbability': 0.17, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0005, 'precipType': 'rain', 'temperature': 45.32, 'apparentTemperature': 41.53, 'dewPoint': 41.54, 'humidity': 0.87, 'pressure': 989.75, 'windSpeed': 6.98, 'windGust': 21.09, 'windBearing': 186, 'cloudCover': 0.8, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 499.39}, {'time': 1712005200, 'icon': 'clear-night', 'summary': 'Clear', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 45.11, 'apparentTemperature': 40.94, 'dewPoint': 41.56, 'humidity': 0.87, 'pressure': 989.94, 'windSpeed': 7.66, 'windGust': 22.13, 'windBearing': 184, 'cloudCover': 0.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 499.12}, {'time': 1712008800, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 45.5, 'apparentTemperature': 40.8, 'dewPoint': 42.29, 'humidity': 0.89, 'pressure': 990.3, 'windSpeed': 9.04, 'windGust': 23.56, 'windBearing': 193, 'cloudCover': 1.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 494.26}, {'time': 1712012400, 'icon': 'partly-cloudy-night', 'summary': 'Partly Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 46.19, 'apparentTemperature': 41.12, 'dewPoint': 43.44, 'humidity': 0.9, 'pressure': 990.61, 'windSpeed': 10.44, 'windGust': 25.27, 'windBearing': 209, 'cloudCover': 0.42, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 493.56}, {'time': 1712016000, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 46.56, 'apparentTemperature': 41.13, 'dewPoint': 44.32, 'humidity': 0.92, 'pressure': 990.95, 'windSpeed': 11.8, 'windGust': 25.76, 'windBearing': 214, 'cloudCover': 1.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 493.17}, {'time': 1712019600, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0019, 'precipProbability': 0.05, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0019, 'precipType': 'rain', 'temperature': 48.24, 'apparentTemperature': 42.5, 'dewPoint': 43.54, 'humidity': 0.84, 'pressure': 991.13, 'windSpeed': 14.43, 'windGust': 25.68, 'windBearing': 217, 'cloudCover': 0.97, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 489.32}, {'time': 1712023200, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0025, 'precipProbability': 0.07, 'precipIntensityError': 0.01, 'precipAccumulation': 0.0025, 'precipType': 'rain', 'temperature': 47.83, 'apparentTemperature': 42.01, 'dewPoint': 44.04, 'humidity': 0.86, 'pressure': 991.36, 'windSpeed': 14.34, 'win ...

# %%
import requests

BASE_URL = "https://api.pirateweather.net/forecast/"
API_KEY = "9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ"

def get_weather(latitude, longitude):
    try:
        # Construct the URL based on the location and API key
        location = f"{latitude},{longitude}"
        url = f"{BASE_URL}{API_KEY}/{location}?exclude=minutely,daily&extend=hourly&tz=auto"

        # Send the request and get the response
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        response.raise_for_status()

        # Parse JSON response
        weather_data = response.json()
        return weather_data
    except requests.exceptions.RequestException as e:
        # Print error message if request was not successful
        print(f"HTTP error occurred: {e}")
        return None

# Example usage:
latitude = input("Enter latitude: ")
longitude = input("Enter longitude: ")

weather_data = get_weather(latitude, longitude)
if weather_data:
    print(weather_data)
# Out:
# Enter latitude: 40.7
# Enter longitude: -74
# {'latitude': 40.7, 'longitude': -74.0, 'timezone': 'America/New_York', 'offset': -4.0, 'elevation': 0, 'currently': {'time': 1712001540, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-day', 'nearestStormDistance': 0, 'nearestStormBearing': 0, 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipType': 'none', 'temperature': 54.23, 'apparentTemperature': 52.06, 'dewPoint': 38.26, 'humidity': 0.57, 'pressure': 1010.7, 'windSpeed': 3.26, 'windGust': 3.63, 'windBearing': 43, 'cloudCover': 0.69, 'uvIndex': 4.35, 'visibility': 10.0, 'ozone': 399.67}, 'hourly': {'summary': 'Cloudy', 'icon': 'cloudy', 'data': [{'time': 1711998000, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0049, 'precipProbability': 0.16, 'precipIntensityError': 0.01, 'precipAccumulation': 0.0049, 'precipType': 'rain', 'temperature': 50.41, 'apparentTemperature': 47.9, 'dewPoint': 37.13, 'humidity': 0.62, 'pressure': 1010.6, 'windSpeed': 6.88, 'windGust': 9.35, 'windBearing': 61, 'cloudCover': 0.87, 'uvIndex': 2.17, 'visibility': 10.0, 'ozone': 400.33}, {'time': 1712001600, 'icon': 'partly-cloudy-day', 'summary': 'Partly Cloudy', 'precipIntensity': 0.0032, 'precipProbability': 0.1, 'precipIntensityError': 0.01, 'precipAccumulation': 0.0032, 'precipType': 'rain', 'temperature': 54.23, 'apparentTemperature': 52.06, 'dewPoint': 38.26, 'humidity': 0.57, 'pressure': 1010.7, 'windSpeed': 3.26, 'windGust': 3.63, 'windBearing': 43, 'cloudCover': 0.69, 'uvIndex': 4.35, 'visibility': 10.0, 'ozone': 399.67}, {'time': 1712005200, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0015, 'precipProbability': 0.03, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0015, 'precipType': 'rain', 'temperature': 54.12, 'apparentTemperature': 51.16, 'dewPoint': 35.56, 'humidity': 0.5, 'pressure': 1012.2, 'windSpeed': 5.49, 'windGust': 6.14, 'windBearing': 7, 'cloudCover': 1.0, 'uvIndex': 2.27, 'visibility': 10.0, 'ozone': 398.48}, {'time': 1712008800, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.001, 'precipProbability': 0.03, 'precipIntensityError': 0.0, 'precipAccumulation': 0.001, 'precipType': 'rain', 'temperature': 52.77, 'apparentTemperature': 48.89, 'dewPoint': 32.07, 'humidity': 0.45, 'pressure': 1012.8, 'windSpeed': 4.81, 'windGust': 7.96, 'windBearing': 26, 'cloudCover': 1.0, 'uvIndex': 0.68, 'visibility': 10.0, 'ozone': 397.86}, {'time': 1712012400, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0005, 'precipProbability': 0.03, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0005, 'precipType': 'rain', 'temperature': 52.09, 'apparentTemperature': 48.36, 'dewPoint': 32.63, 'humidity': 0.47, 'pressure': 1014.0, 'windSpeed': 3.62, 'windGust': 7.12, 'windBearing': 16, 'cloudCover': 1.0, 'uvIndex': 0.11, 'visibility': 10.0, 'ozone': 396.13}, {'time': 1712016000, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 51.53, 'apparentTemperature': 49.36, 'dewPoint': 38.26, 'humidity': 0.6, 'pressure': 1014.7, 'windSpeed': 2.3, 'windGust': 6.56, 'windBearing': 346, 'cloudCover': 1.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 392.68}, {'time': 1712019600, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 51.19, 'apparentTemperature': 50.73, 'dewPoint': 43.32, 'humidity': 0.74, 'pressure': 1014.9, 'windSpeed': 2.79, 'windGust': 7.68, 'windBearing': 323, 'cloudCover': 1.0, 'uvIndex': 0.0, 'visibility': 10.0, 'ozone': 389.2}, {'time': 1712023200, 'icon': 'cloudy', 'summary': 'Cloudy', 'precipIntensity': 0.0, 'precipProbability': 0.0, 'precipIntensityError': 0.0, 'precipAccumulation': 0.0, 'precipType': 'none', 'temperature': 50.97, 'apparentTemperature': 50.84, 'dewPoint': 44.22, 'humidity': 0.77, 'pressure': 1014.3, 'windSpeed': 1.73,  ...

# %%
import requests

BASE_URL = "https://api.pirateweather.net/forecast/"
API_KEY = "9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ"

def get_weather(location):
    try:
        # Construct the URL based on the location and API key
        if location.replace(',', '').replace('.', '').isdigit():
            # Assume coordinates
            url = f"{BASE_URL}{API_KEY}/{location}?exclude=minutely,daily&extend=hourly&tz=auto"
        else:
            # Assume city or zip code
            url = f"{BASE_URL}{API_KEY}/{location}?exclude=minutely,daily&extend=hourly&tz=auto"

        # Send the request and get the response
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        response.raise_for_status()

        # Parse JSON response
        weather_data = response.json()
        return weather_data
    except requests.exceptions.RequestException as e:
        # Print error message if request was not successful
        print(f"HTTP error occurred: {e}")
        return None

# Example usage:
location = input("Enter city, zip code, or coordinates: ")
weather_data = get_weather(location)
if weather_data:
    print(weather_data)
# Out:
# Enter city, zip code, or coordinates: 40.7, -74
# HTTP error occurred: 502 Server Error: Bad Gateway for url: https://api.pirateweather.net/forecast/9Pn8CfvVbD6NaHdukQWoo0T5MaFGXwVJ/40.7,%20-74?exclude=minutely,daily&extend=hourly&tz=auto
